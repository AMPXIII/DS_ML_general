# %%
import pandas as pd
import re

# %%
df = pd.read_csv('./loan_data_track1.csv')

# %%
df.head()
# Out:
#   checking_status  duration                        loan_history  \
# 0            <0DM         6  Critical_acct_other_loans_existing
# 1      0_to_200DM        48        Existing_loans_paid_till_now
# 2            None        12  Critical_acct_other_loans_existing
# 3            <0DM        42        Existing_loans_paid_till_now
# 4            <0DM        24                       Delay_in_past
#
#                purpose  loan_amount              savings_status employment  \
# 0     radio/television         1169  Unknown_or_no_savings_acct      >7yrs
# 1     radio/television         5951                      <100DM  1_to_4yrs
# 2            education         2096                      <100DM  4_to_7yrs
# 3  furniture/equipment         7882                      <100DM  4_to_7yrs
# 4              new_car         4870                      <100DM  1_to_4yrs
#
#    installment_commitment                    personal_status other_parties  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
# checking_status           1000 non-null object
# duration                  1000 non-null int64
# loan_history              1000 non-null object
# purpose                   1000 non-null object
# loan_amount               1000 non-null int64
# savings_status            1000 non-null object
# employment                1000 non-null object
# installment_commitment    1000 non-null int64
# personal_status           1000 non-null object
# other_parties             1000 non-null object
# residence_since           1000 non-null int64
# property_magnitude        1000 non-null object
# age                       1000 non-null int64
# other_payment_plans       1000 non-null object
# housing                   1000 non-null object
# existing_loans            1000 non-null object
# job                       1000 non-null object
# num_dependents            1000 non-null int64
# ...

# %%
df.accepted.value_counts()
# Out:
# 2    700
# 1    300
# Name: accepted, dtype: int64

# %%
df.accepted = df.accepted.map({1:0, 2:1})

# %%
pct_accepted = df.accepted.value_counts()[1] / df.shape[0]
pct_accepted
# Out:
# 0.7

# %%
df.purpose.mode()
# Out:
# 0    radio/television
# dtype: object

# %%
df.purpose.value_counts()
# Out:
# radio/television       280
# new_car                234
# furniture/equipment    181
# used_car               103
# business                97
# education               50
# repairs                 22
# domestic_appliances     12
# other                   12
# retraining               9
# Name: purpose, dtype: int64

# %%
df.groupby('accepted').mean()['age']
# Out:
# accepted
# 0    33.963333
# 1    36.224286
# Name: age, dtype: float64

# %%
df.existing_loans.apply(lambda x: re.sub("\D", "", x))
# Out:
# 0       22
# 1        1
# 2        1
# 3        1
# 4       22
# 5        1
# 6        1
# 7        1
# 8        1
# 9       22
# 10       1
# 11       1
# 12       1
# 13      22
# 14       1
# 15       1
# 16      22
# 17     333
# 18       1
# 19       1
# 20     333
# 21       1
# 22      22
# 23       1
# 24      22
# 25       1
# 26       1
# 27      22
# 28       1
# 29      22
#       ...
# 970      1
# 971      1
# 972     22
# 973      1
# 974      1
# 975      1
# 976      1
# 977     22
# 978     22
# 979      1
# 980      1
# 981      1
# 982      1
# 983      1
# 984     22
# 985     22
# 986     22
# 987      1
# 988      1
# 989     22
# 990     22
# 991      1
# 992     22
# 993      1
# 994      1
# 995      1
# 996      1
# 997      1
# 998      1
# 999      1
# Name: existing_loans, Length: 1000, dtype: object

# %%
df_m = df[['age','checking_status','duration','job','purpose','accepted']]
df_m.head()
# Out:
#    age checking_status  duration                        job  \
# 0   67            <0DM         6  skilled_employee/official
# 1   22      0_to_200DM        48  skilled_employee/official
# 2   49            None        12         unskilled_resident
# 3   45            <0DM        42  skilled_employee/official
# 4   53            <0DM        24  skilled_employee/official
#
#                purpose  accepted
# 0     radio/television         1
# 1     radio/television         0
# 2            education         1
# 3  furniture/equipment         1
# 4              new_car         0

# %%
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
# age                1000 non-null int64
# checking_status    1000 non-null object
# duration           1000 non-null int64
# job                1000 non-null object
# purpose            1000 non-null object
# accepted           1000 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 47.0+ KB

# %%
df_m.purpose = df_m.purpose.astype('category')
df_m.checking_status = df_m.checking_status.astype('category')
df_m.job = df_m.job.astype('category')
# Out:
# C:\Users\PcCom\Anaconda3\envs\ml_env\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
# age                1000 non-null int64
# checking_status    1000 non-null category
# duration           1000 non-null int64
# job                1000 non-null category
# purpose            1000 non-null category
# accepted           1000 non-null int64
# dtypes: category(3), int64(3)
# memory usage: 27.2 KB

# %%
df_m_dummified = pd.get_dummies(df_m, columns = ['checking_status','job','purpose'], drop_first=True)

# %%
df_m_dummified.head()
# Out:
#    age  duration  accepted  checking_status_<0DM  checking_status_>200DM  \
# 0   67         6         1                     1                       0
# 1   22        48         0                     0                       0
# 2   49        12         1                     0                       0
# 3   45        42         1                     1                       0
# 4   53        24         0                     1                       0
#
#    checking_status_None  job_skilled_employee/official  \
# 0                     0                              1
# 1                     0                              1
# 2                     1                              0
# 3                     0                              1
# 4                     0                              1
#
#    job_unemployed/unskilled_nonresident  job_unskilled_resident  \
# 0                                     0                       0
# ...

# %%
X = df_m_dummified.drop('accepted', axis=1)
y = df_m_dummified['accepted']

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr_clf = LogisticRegression()

# %%
lr_clf.fit(X,y)
# Out:
# C:\Users\PcCom\Anaconda3\envs\ml_env\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
lr_clf.score(X,y)
# Out:
# 0.747

# %%
from sklearn.metrics import recall_score, precision_score

# %%
print('Recall: ',recall_score(y, lr_clf.predict(X)))
print('Precision: ',precision_score(y, lr_clf.predict(X)))
# Out:
# Recall:  0.8985714285714286
# Precision:  0.7755856966707768

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
sc.fit(X)
# Out:
# C:\Users\PcCom\Anaconda3\envs\ml_env\lib\site-packages\sklearn\preprocessing\data.py:617: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_std = sc.transform(X)
# Out:
# C:\Users\PcCom\Anaconda3\envs\ml_env\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.

# %%
lr_clf_std = LogisticRegression()
lr_clf_std.fit(X_std,y)
print('Accuracy: ', lr_clf_std.score(X_std,y))
print('Recall: ',recall_score(y, lr_clf_std.predict(X_std)))
print('Precision: ',precision_score(y, lr_clf_std.predict(X_std)))
# Out:
# Accuracy:  0.751
# Recall:  0.9
# Precision:  0.7787391841779975
# C:\Users\PcCom\Anaconda3\envs\ml_env\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from statistics import mean, stdev
from math import exp

# %%
# %matplotlib inline

# %%
# Checking the importance of a coefficient by computing its "Beta"
data = pd.read_csv("loan_data_track1.csv")
numeric_model_fields = ["age", "duration", "loan_amount", "installment_commitment"]
X = data[numeric_model_fields]
X.insert(len(X.columns), 'own_telephone_Yes', pd.get_dummies(data['own_telephone'])['Yes'])
X_col_list = list(X.columns)
y = data["accepted"]
logistic_model = LogisticRegression()
sample_size = 0.6
result_list = []
for i in range(100):
    sample_index = random.sample(range(len(data)),int(len(data) * sample_size))
    model = logistic_model.fit(X.ix[sample_index], y.ix[sample_index])
    result_list.append(exp(model.coef_[0][X_col_list.index('own_telephone_Yes')]))
    
print(mean(result_list))
print(stdev(result_list))
plt.hist(result_list)
# Out:
# C:\Users\PcCom\Anaconda3\envs\ml_env\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   del sys.path[0]
# C:\Users\PcCom\Anaconda3\envs\ml_env\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\PcCom\Anaconda3\envs\ml_env\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   del sys.path[0]
# ...
